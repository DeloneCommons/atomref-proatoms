# %% [markdown]
# # atomref-proatoms release artifact inspection
#
# This notebook is a lightweight guide for inspecting generated profile, radii, and QA artifacts. It reads tables from `data/`; it does not run SCF calculations and does not define the production workflow.

# %% [markdown]
# The current release artifact set contains four dataset directories under `data/profiles/`, `data/radii/`, and `data/qa/`. The expected row counts are 430 for `x2c-QZVPall`, 501 for `dyall-v4z`, 106 for `x2c-QZVPall-s` anions, and 91 for `dyall-av4z` selected anions.

# %%
import json
from pathlib import Path

import pandas as pd

qa_root = Path('../../data/qa')
summary = pd.read_csv(qa_root / 'qa_summary.csv')
summary
# Out:
#                                           dataset_id       basis_id  \
# 0            pbe0_sfx2c_x2cqzvpall_h-rn_spherical_v2    x2c-QZVPall
# 1              pbe0_sfx2c_dyallv4z_h-lr_spherical_v2      dyall-v4z
# 2    pbe0_sfx2c_x2cqzvpalls_h-rn_anions_spherical_v2  x2c-QZVPall-s
# 3  pbe0_sfx2c_dyallav4z_h-ba_hf-ra_anions_spheric...     dyall-av4z
#
#    state_count  passed_count  failed_count  max_abs_electron_count_error_qa  \
# 0          430           430             0                     2.302158e-12
# 1          501           501             0                     2.430056e-12
# 2          106           106             0                     2.330580e-12
# 3           91            91             0                     2.273737e-12
#
#    max_rel_angular_sigma  linear_dependency_warning_count
# 0           1.560673e-14                                0
# 1           3.750386e-15                              266
# 2           3.850762e-15                               19
# ...

# %%
basis_meta = json.loads((qa_root / 'basis_sensitivity' / 'metadata.json').read_text())
basis_meta['pair_outputs']
# Out:
# {'basis_sensitivity_dyall': {'output_dir': 'data/qa/basis_sensitivity/dyall-v4z',
#   'rows_csv': 'data/qa/basis_sensitivity/dyall-v4z/basis_sensitivity.csv',
#   'summary_csv': 'data/qa/basis_sensitivity/dyall-v4z/basis_sensitivity_summary.csv',
#   'outliers_csv': 'data/qa/basis_sensitivity/dyall-v4z/basis_sensitivity_outliers.csv',
#   'metric_distributions_csv': 'data/qa/basis_sensitivity/dyall-v4z/basis_sensitivity_metric_distributions.csv',
#   'row_count': '91',
#   'summary_count': '1',
#   'outlier_count': '14',
#   'metric_distribution_count': '121'},
#  'basis_sensitivity_x2c_optional': {'output_dir': 'data/qa/basis_sensitivity/x2c-QZVPall',
#   'rows_csv': 'data/qa/basis_sensitivity/x2c-QZVPall/basis_sensitivity.csv',
#   'summary_csv': 'data/qa/basis_sensitivity/x2c-QZVPall/basis_sensitivity_summary.csv',
#   'outliers_csv': 'data/qa/basis_sensitivity/x2c-QZVPall/basis_sensitivity_outliers.csv',
# ...

# %% [markdown]
# For release validation, prefer the command-line checker:
#
# ```bash
# python scripts/check_profile_artifacts.py --require-generated
# ```
